# %% [markdown]
# ---
#
# Import everything again.
#
# ---

# %%
import os
import json
import shutil
import hashlib
import logging
import re
from pathlib import Path
from collections import Counter, defaultdict
import pandas as pd
import numpy as np
import yaml
from PIL import Image
from PIL import UnidentifiedImageError
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt

print("All required libraries imported successfully")
# Out:
# All required libraries imported successfully

# %% [markdown]
# ---
#
# Configure all paths again.
#
# ---

# %%
# Project root
PROJECT_ROOT = Path.cwd().parents[1]

# Configuration
CONFIG_DIR = PROJECT_ROOT / "config"
YAML_PATH = CONFIG_DIR / "download_sheet.yaml"

# Dataset directories
DATASET_DIR = PROJECT_ROOT / "datasets"

RAW_DIR = DATASET_DIR / "raw"
VALIDATED_DIR = DATASET_DIR / "validated"
INVALID_DIR = DATASET_DIR / "invalid"
PROCESSED_DIR = DATASET_DIR / "processed"
INTERIM_DIR = DATASET_DIR / "interim"
DATASET_V2_DIR = DATASET_DIR / "dataset_v2"
REPORT_DIR = DATASET_DIR / "reports"

# Display paths
print(f"Project Root : {PROJECT_ROOT}")
print(f"Config       : {CONFIG_DIR}")
print(f"Raw          : {RAW_DIR}")
print(f"Validated    : {VALIDATED_DIR}")
print(f"Invalid      : {INVALID_DIR}")
print(f"Processed    : {PROCESSED_DIR}")
print(f"Interim      : {INTERIM_DIR}")
print(f"Dataset V2   : {DATASET_V2_DIR}")
print(f"Reports      : {REPORT_DIR}")
print(f"YAML File    : {YAML_PATH}")
# Out:
# Project Root : D:\SIT374\WalkBuddy-T2-2026\ML_side
# Config       : D:\SIT374\WalkBuddy-T2-2026\ML_side\config
# Raw          : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw
# Validated    : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\validated
# Invalid      : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\invalid
# Processed    : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\processed
# Interim      : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\interim
# Dataset V2   : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\dataset_v2
# Reports      : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\reports
# YAML File    : D:\SIT374\WalkBuddy-T2-2026\ML_side\config\download_sheet.yaml

# %% [markdown]
# ---
#
# Setting up the log to check activities
#
# ---

# %%
# --- Logging setup ---
timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")
LOG_PATH = REPORT_DIR / f"validation_log_{timestamp}.log"

logger = logging.getLogger("validation")
logger.setLevel(logging.INFO)
logger.handlers.clear()  # avoid duplicate handlers if cell is re-run

file_handler = logging.FileHandler(LOG_PATH, encoding="utf-8")
file_handler.setFormatter(logging.Formatter("%(asctime)s | %(levelname)s | %(message)s"))
logger.addHandler(file_handler)

stream_handler = logging.StreamHandler()
stream_handler.setFormatter(logging.Formatter("%(levelname)s: %(message)s"))
logger.addHandler(stream_handler)

logger.info("Validation run started.")
logger.info(f"Log file created at: {LOG_PATH}")

# Structured results collector — will become the CSV report later
validation_results = []
# Out:
# INFO: Validation run started.
# INFO: Log file created at: D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\reports\validation_log_20260804_012057.log

# %% [markdown]
# ---
#
# Read the config file again
#
# ---

# %%
with open(YAML_PATH, "r", encoding="utf-8") as file:
    dataset_config = yaml.safe_load(file)

print(f"Successfully loaded {YAML_PATH.name}")
print(f"Datasets found: {len(dataset_config)}")
logger.info(f"Successfully loaded YAML config from {YAML_PATH}")
# Out:
# INFO: Successfully loaded YAML config from D:\SIT374\WalkBuddy-T2-2026\ML_side\config\download_sheet.yaml
# Successfully loaded download_sheet.yaml
# Datasets found: 1

# %% [markdown]
# ---
#
# Extract dataset entries
#
# ---

# %%
datasets = dataset_config["datasets"]
dataset_names = list(datasets.keys())

logger.info(f"Extracted {len(dataset_names)} dataset entries from YAML.")
print(f"Total datasets in YAML: {len(dataset_names)}")
for name, meta in datasets.items():
    print(f"  - {name} | source: {meta.get('source')} | status: {meta.get('status')}")
# Out:
# INFO: Extracted 19 dataset entries from YAML.
# Total datasets in YAML: 19
#   - obstacle_detection_roboflow | source: roboflow | status: approved
#   - obstacle_detection_kaggle | source: kaggle | status: approved
#   - obstacle_detection_huggingface | source: huggingface | status: rejected
#   - indoor_object_detection | source: kaggle | status: approved
#   - mapillary_vistas | source: manual | status: approved
#   - light_poles | source: kaggle | status: approved
#   - fpv_crosswalk_segmentation | source: kaggle | status: approved
#   - pedestrian_detection | source: kaggle | status: approved
#   - road_sign_detection | source: kaggle | status: approved
#   - antic_chairs | source: kaggle | status: approved
#   - doors_detection | source: kaggle | status: approved
#   - indoor_objects_roboflow | source: roboflow | status: approved
#   - indoor_detection_vineeth | source: roboflow | status: approved
#   - indoor_objects_5iwhq | source: roboflow | status: approved
#   - revised_pedestrian_obstacle_detection | source: roboflow | status: approved
#   - pedestrian_walk | source: roboflow | status: approved
#   - outdoor_objects | source: roboflow | status: approved
#   - footpath_detection | source: roboflow | status: approved
#   - stairs_detection | source: roboflow | status: approved

# %% [markdown]
# ---
#
# Check if all data successfully downloaded
#
# ---

# %%
folder_check_results = []

for name, meta in datasets.items():
    status = meta.get("status")
    source = meta.get("source")
    folder_name = meta.get("folder")
    expected_path = RAW_DIR / source / folder_name

    if status == "rejected":
        logger.info(f"[SKIPPED] {name} — status is 'rejected' in YAML, not validated.")
        folder_check_results.append({
            "dataset": name,
            "path": str(expected_path),
            "exists": None,
            "file_count": None,
            "verdict": "SKIPPED"
        })
        continue

    if not expected_path.exists():
        logger.warning(f"[MISSING] {name} — expected folder not found: {expected_path}")
        folder_check_results.append({
            "dataset": name,
            "path": str(expected_path),
            "exists": False,
            "file_count": 0,
            "verdict": "MISSING"
        })
        continue

    file_count = sum(1 for f in expected_path.rglob("*") if f.is_file())

    if file_count == 0:
        logger.warning(f"[EMPTY] {name} — folder exists but contains no files: {expected_path}")
        verdict = "EMPTY"
    else:
        logger.info(f"[OK] {name} — found {file_count} files in {expected_path}")
        verdict = "OK"

    folder_check_results.append({
        "dataset": name,
        "path": str(expected_path),
        "exists": True,
        "file_count": file_count,
        "verdict": verdict
    })

folder_check_df = pd.DataFrame(folder_check_results)
print(folder_check_df.to_string(index=False))
# Out:
# INFO: [OK] obstacle_detection_roboflow — found 18369 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow
# INFO: [OK] obstacle_detection_kaggle — found 48658 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle
# INFO: [SKIPPED] obstacle_detection_huggingface — status is 'rejected' in YAML, not validated.
# INFO: [OK] indoor_object_detection — found 2692 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\indoor_object_detection
# INFO: [OK] mapillary_vistas — found 165009 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\manual\mapillary_vistas
# INFO: [OK] light_poles — found 1826 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\light_poles
# INFO: [OK] fpv_crosswalk_segmentation — found 6600 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\fpv_crosswalk_segmentation
# INFO: [OK] pedestrian_detection — found 6 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\pedestrian_detection
# INFO: [OK] road_sign_detection — found 1754 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\road_sign_detection
# INFO: [OK] antic_chairs — found 1403 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\antic_chairs
# INFO: [OK] doors_detection — found 208 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\doors_detection
# INFO: [OK] indoor_objects_roboflow — found 263 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\indoor_objects_roboflow
# INFO: [OK] indoor_detection_vineeth — found 5783 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\indoor_detection_vineeth
# INFO: [OK] indoor_objects_5iwhq — found 2981 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\indoor_objects_5iwhq
# INFO: [OK] revised_pedestrian_obstacle_detection — found 12687 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\pedestrian_obstacle_detection
# INFO: [OK] pedestrian_walk — found 2003 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\pedestrian_walk
# INFO: [OK] outdoor_objects — found 4803 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\outdoor_objects
# INFO: [OK] footpath_detection — found 3377 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\footpath_detection
# INFO: [OK] stairs_detection — found 469 files in D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\stairs_detection
#                               dataset                                                                                        path exists  file_count verdict
#           obstacle_detection_roboflow       D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow   True     18369.0      OK
#             obstacle_detection_kaggle           D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle   True     48658.0      OK
#        obstacle_detection_huggingface D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\huggingface\obstacle_detection_huggingface   None         NaN SKIPPED
#               indoor_object_detection             D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\indoor_object_detection   True      2692.0      OK
#                      mapillary_vistas                    D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\manual\mapillary_vistas   True    165009.0      OK
#                           light_poles                         D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\light_poles   True      1826.0      OK
#            fpv_crosswalk_segmentation          D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\fpv_crosswalk_segmentation   True      6600.0      OK
#                  pedestrian_detection                D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\pedestrian_detection   True         6.0      OK
#                   road_sign_detection                 D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\road_sign_detection   True      1754.0      OK
#                          antic_chairs                        D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\antic_chairs   True      1403.0      OK
#                       doors_detection                     D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\doors_detection   True       208.0      OK
#               indoor_objects_roboflow           D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\indoor_objects_roboflow   True       263.0      OK
#              indoor_detection_vineeth          D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\indoor_detection_vineeth   True      5783.0      OK
#                  indoor_objects_5iwhq              D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\indoor_objects_5iwhq   True      2981.0      OK
# revised_pedestrian_obstacle_detection     D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\pedestrian_obstacle_detection   True     12687.0      OK
#                       pedestrian_walk                   D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\pedestrian_walk   True      2003.0      OK
#                       outdoor_objects                   D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\outdoor_objects   True      4803.0      OK
#                    footpath_detection                D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\footpath_detection   True      3377.0      OK
#                      stairs_detection                  D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\stairs_detection   True       469.0      OK

# %%
IMAGE_EXTS = {".jpg", ".jpeg", ".png"}
VIDEO_EXTS = {".avi", ".mp4", ".mov", ".mkv"}
TABULAR_EXTS = {".csv", ".xlsx", ".xls"}
TEXT_LABEL_EXTS = {".txt", ".json", ".xml"}
METADATA_EXTS = {".yaml", ".yml", ".md", ".py"}
METADATA_FILENAMES = {"license", "readme", "readme.txt", "changelog", "notice"}


def check_file(filepath: Path):
    """Return (status, reason) for a single file."""
    ext = filepath.suffix.lower()
    stem_lower = filepath.name.lower()

    try:
        # Check filename-based metadata first (LICENSE, README have no extension)
        if stem_lower in METADATA_FILENAMES:
            with open(filepath, "r", encoding="utf-8", errors="strict") as f:
                f.read()
            return "METADATA", None

        if ext in IMAGE_EXTS:
            with Image.open(filepath) as img:
                img.verify()
            return "OK", None

        elif ext in VIDEO_EXTS:
            cap = cv2.VideoCapture(str(filepath))
            if not cap.isOpened():
                cap.release()
                return "CORRUPT", "cv2 could not open video"
            ret, frame = cap.read()
            cap.release()
            if not ret:
                return "CORRUPT", "video opened but no readable frame"
            return "OK", None

        elif ext in TABULAR_EXTS:
            if ext == ".csv":
                pd.read_csv(filepath, nrows=5)
            else:
                pd.read_excel(filepath, nrows=5)
            return "OK", None

        elif ext in TEXT_LABEL_EXTS:
            if filepath.stat().st_size == 0:
                return "CORRUPT", "empty file"
            with open(filepath, "r", encoding="utf-8", errors="strict") as f:
                f.read()
            return "OK", None

        elif ext in METADATA_EXTS:
            with open(filepath, "r", encoding="utf-8", errors="strict") as f:
                f.read()
            return "METADATA", None

        else:
            return "UNRECOGNIZED", f"unhandled extension: {ext or '(none)'}"

    except Exception as e:
        return "CORRUPT", str(e)


# --- Run integrity check per dataset ---
file_integrity_results = []   # per-dataset summary
file_level_issues = []        # every individual bad file, for the log/report

for row in folder_check_df.itertuples():
    if row.verdict != "OK":
        continue  # skip SKIPPED / MISSING / EMPTY, nothing to check

    dataset_name = row.dataset
    dataset_path = Path(row.path)

    ok_count = 0
    corrupt_count = 0
    metadata_count = 0
    unrecognized_count = 0

    all_files = [f for f in dataset_path.rglob("*") if f.is_file()]

    for f in tqdm(all_files, desc=dataset_name, leave=False):
        status, reason = check_file(f)

        if status == "OK":
            ok_count += 1
        elif status == "METADATA":
            metadata_count += 1
        elif status == "CORRUPT":
            corrupt_count += 1
            logger.warning(f"[CORRUPT] {dataset_name} — {f} — {reason}")
            file_level_issues.append({
                "dataset": dataset_name,
                "file": str(f),
                "issue": reason
            })
        elif status == "UNRECOGNIZED":
            unrecognized_count += 1
            logger.info(f"[UNRECOGNIZED] {dataset_name} — {f} — {reason}")

    logger.info(
        f"[INTEGRITY] {dataset_name} — OK: {ok_count}, CORRUPT: {corrupt_count}, "
        f"METADATA: {metadata_count}, UNRECOGNIZED: {unrecognized_count}"
    )

    file_integrity_results.append({
        "dataset": dataset_name,
        "total_files": len(all_files),
        "ok": ok_count,
        "corrupt": corrupt_count,
        "metadata": metadata_count,
        "unrecognized": unrecognized_count
    })

file_integrity_df = pd.DataFrame(file_integrity_results)
print(file_integrity_df.to_string(index=False))
# Out:
# obstacle_detection_roboflow:   5%|██▌                                              | 983/18369 [00:21<07:22, 39.31it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\valid\labels\340146150_137459042456892_8086499857949427109_n_jpg.rf.e2155cb5151327e0f6954c41d3848681.txt — empty file
# obstacle_detection_roboflow:   7%|███▏                                            | 1208/18369 [00:27<07:41, 37.21it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\valid\labels\f6301-h-stellplatten_jpg.rf.84cb958465cecf0f4b3f8f9036899d31.txt — empty file
# obstacle_detection_roboflow:   7%|███▎                                            | 1258/18369 [00:28<06:53, 41.36it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\valid\labels\images18_jpg.rf.5c744e438ef22f5a846c9fbd8b0920ec.txt — empty file
# obstacle_detection_roboflow:   7%|███▎                                            | 1280/18369 [00:28<06:26, 44.21it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\valid\labels
/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\train\labels\water-draining-cave_jpg.rf.3b84d49dedb5aba56b1ce0e8a6441b05.txt — empty file
# obstacle_detection_roboflow:  94%|████████████████████████████████████████████▍  | 17352/18369 [06:37<00:24, 42.35it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\train\labels\water-pollution_jpg.rf.35961b59228b50325bd4a8a5acc9cce4.txt — empty file
# obstacle_detection_roboflow:  98%|█████████████████████████████████████████████▉ | 17969/18369 [06:51<00:11, 35.10it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\354347776243379_jpg.rf.ba7d1bd9f765ad1ac58123b568b09b83.txt — empty file
# obstacle_detection_roboflow:  99%|██████████████████████████████████████████████▎| 18100/18369 [06:54<00:06, 40.55it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\images11_jpg.rf.89981862ad78db7e694768164e610b04.txt — empty file
# obstacle_detection_roboflow:  99%|██████████████████████████████████████████████▎| 18105/18369 [06:54<00:06, 41.43it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\images18_jpg.rf.b0e65916ee33abc46aaabe8ebd602b4a.txt — empty file
# obstacle_detection_roboflow:  99%|██████████████████████████████████████████████▎| 18110/18369 [06:54<00:06, 41.63it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\img-1142_jpg.rf.a8d3995655da1858e4eb87507e797397.txt — empty file
# obstacle_detection_roboflow:  99%|██████████████████████████████████████████████▌| 18210/18369 [06:57<00:04, 38.74it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\img-3507_jpg.rf.34c0fcc945c5cabbeb086588c60b71d9.txt — empty file
# obstacle_detection_roboflow:  99%|██████████████████████████████████████████████▌| 18215/18369 [06:57<00:03, 41.45it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\img-3612_jpeg.rf.63e9237d5b961a2baf67ae66a9590759.txt — empty file
# obstacle_detection_roboflow: 100%|██████████████████████████████████████████████▊| 18299/18369 [07:00<00:01, 36.42it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\ne-01_jpg.rf.6898844c01ecbb51a451a4bbbda4df56.txt — empty file
# obstacle_detection_roboflow: 100%|██████████████████████████████████████████████▉| 18334/18369 [07:00<00:00, 39.80it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\rustic-clay-oven_jpg.rf.83a10e66f9e711976bdb1aabf5fc03f8.txt — empty file
# obstacle_detection_roboflow: 100%|██████████████████████████████████████████████▉| 18354/18369 [07:01<00:00, 37.82it/s]WARNING: [CORRUPT] obstacle_detection_roboflow — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\test\labels\Tramway_Berlin_-_Tatra_KT4D-t_jpg.rf.af79c84e37dd6090eb25a645925fc8eb.txt — empty file
# INFO: [INTEGRITY] obstacle_detection_roboflow — OK: 18257, CORRUPT: 111, METADATA: 1, UNRECOGNIZED: 0
# obstacle_detection_kaggle:   7%|███▋                                              | 3582/48658 [01:21<15:50, 47.43it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_20883.txt — empty file
# obstacle_detection_kaggle:  12%|██████▏                                           | 5990/48658 [02:11<15:11, 46.83it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_23289.txt — empty file
# obstacle_detection_kaggle:  12%|██████▏                                           | 5995/48658 [02:11<15:41, 45.34it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_23297.txt — empty file
# obstacle_detection_kaggle:  12%|██████▏                                           | 6031/48658 [02:12<14:30, 48.97it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_23331.txt — empty file
# WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_23335.txt — empty file
# obstacle_detection_kaggle:  13%|██████▎                                           | 6201/48658 [02:16<13:59, 50.58it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_23505.txt — empty file
# obstacle_detection_kaggle:  13%|██████▍                                           | 6207/48658 [02:16<14:01, 50.43it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_23510.txt — empty file
# obstacle_detection_kaggle:  13%|██████▍                                           | 6213/48658 [02:16<14:04, 50.28it/s]WARNING: [CORRUPT] obstacle_detection_kaggle — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\obstacle_detection_kaggle\ROD-Dataset\dataset\valid\labels\IMG_
\labels\y2mate_bz-Walking-New-York-City-on-a-Spring-like-Day-Manhattan-NYC-Waking-Tour_mp4-1392_jpg.rf.55177c6e6bb4e46a017bbf1ad4a76fc3.txt — empty file
# INFO: [INTEGRITY] footpath_detection — OK: 3227, CORRUPT: 149, METADATA: 1, UNRECOGNIZED: 0
# stairs_detection:  14%|████████▋                                                      | 65/469 [00:01<00:07, 54.27it/s]WARNING: [CORRUPT] stairs_detection — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\stairs_detection\valid\labels\-66-_jpg.rf.498a046124d881b440bcca8cacc80955.txt — empty file
# stairs_detection:  20%|████████████▉                                                  | 96/469 [00:01<00:07, 50.56it/s]WARNING: [CORRUPT] stairs_detection — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\stairs_detection\valid\labels\th_jpg.rf.4f257a6df2c6ff0cbf7cdbff3d9afa3b.txt — empty file
# stairs_detection:  66%|█████████████████████████████████████████                     | 311/469 [00:05<00:02, 55.72it/s]WARNING: [CORRUPT] stairs_detection — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\stairs_detection\train\labels\-57-_jpg.rf.f3262a149042751b561e4d2e71f145e7.txt — empty file
# stairs_detection:  68%|██████████████████████████████████████████▏                   | 319/469 [00:05<00:02, 61.95it/s]WARNING: [CORRUPT] stairs_detection — D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\stairs_detection\train\labels\-67-_jpg.rf.eff0dc79fee972f271ac948e96de0c40.txt — empty file
# INFO: [INTEGRITY] stairs_detection — OK: 464, CORRUPT: 4, METADATA: 1, UNRECOGNIZED: 0
#                               dataset  total_files     ok  corrupt  metadata  unrecognized
#           obstacle_detection_roboflow        18369  18257      111         1             0
#             obstacle_detection_kaggle        48658  48557       99         2             0
#               indoor_object_detection         2692   2544      147         1             0
#                      mapillary_vistas       165009 165006        0         3             0
#                           light_poles         1826   1826        0         0             0
#            fpv_crosswalk_segmentation         6600   6600        0         0             0
#                  pedestrian_detection            6      6        0         0             0
#                   road_sign_detection         1754   1754        0         0             0
#                          antic_chairs         1403   1403        0         0             0
#                       doors_detection          208    208        0         0             0
#               indoor_objects_roboflow          263    262        0         1             0
#              indoor_detection_vineeth         5783   5781        1         1             0
#                  indoor_objects_5iwhq         2981   2977        3         1             0
# revised_pedestrian_obstacle_detection        12687  12529      157         1             0
#                       pedestrian_walk         2003   2002        0         1             0
#                       outdoor_objects         4803   4763       39         1             0
#                    footpath_detection         3377   3227      149         1             0
#                      stairs_detection          469    464        4         1             0

# %% [markdown]
# ---
#
# Separate and copy corrupted files into invalid
#
# ---

# %%
issues_df = pd.DataFrame(file_level_issues)
copied_invalid = []

for row in issues_df.itertuples():
    dataset_name = row.dataset
    src_path = Path(row.file)

    # Find this dataset's raw root so we can preserve its internal folder structure
    dataset_row = folder_check_df[folder_check_df["dataset"] == dataset_name].iloc[0]
    dataset_raw_root = Path(dataset_row["path"])

    # Path of the file relative to its dataset root (keeps images/labels/... structure intact)
    relative_path = src_path.relative_to(dataset_raw_root)
    dest_path = INVALID_DIR / dataset_name / relative_path

    dest_path.parent.mkdir(parents=True, exist_ok=True)

    try:
        shutil.copy2(src_path, dest_path)
        logger.warning(f"[MOVED TO INVALID] {dataset_name} — {relative_path} — reason: {row.issue}")
        copied_invalid.append({
            "dataset": dataset_name,
            "file": str(relative_path),
            "reason": row.issue,
            "dest": str(dest_path)
        })
    except Exception as e:
        logger.error(f"[COPY FAILED] {dataset_name} — {relative_path} — {e}")

copied_invalid_df = pd.DataFrame(copied_invalid)
print(f"Copied {len(copied_invalid_df)} corrupt files into invalid/")
print(copied_invalid_df.groupby("dataset").size().to_string())
# Out:
# WARNING: [MOVED TO INVALID] obstacle_detection_roboflow — valid\labels
# %%
##### structure_survey = []

for row in folder_check_df.itertuples():
    if row.verdict != "OK":
        continue

    dataset_name = row.dataset
    dataset_path = Path(row.path)

    # Top-level subfolders inside this dataset (e.g. images/, labels/, train/, etc.)
    subfolders = sorted([p.name for p in dataset_path.iterdir() if p.is_dir()])

    # Count files by extension at every depth, so we can see if labels exist anywhere at all
    ext_counts = Counter(f.suffix.lower() for f in dataset_path.rglob("*") if f.is_file())
    has_labels = any(ext in {".txt", ".xml", ".json"} for ext in ext_counts)

    structure_survey.append({
        "dataset": dataset_name,
        "subfolders": subfolders if subfolders else "(flat, no subfolders)",
        "has_label_files": has_labels,
        "image_count": ext_counts.get(".jpg", 0) + ext_counts.get(".jpeg", 0) + ext_counts.get(".png", 0),
        "label_count": ext_counts.get(".txt", 0) + ext_counts.get(".xml", 0) + ext_counts.get(".json", 0)
    })

structure_df = pd.DataFrame(structure_survey)
pd.set_option("display.max_colwidth", None)
print(structure_df.to_string(index=False))
# Out:
#                               dataset                      subfolders  has_label_files  image_count  label_count
#           obstacle_detection_roboflow            [test, train, valid]             True         9183         9185
#             obstacle_detection_kaggle                   [ROD-Dataset]             True        24326        24327
#               indoor_object_detection            [test, train, valid]             True         1349         1342
#                      mapillary_vistas [testing, training, validation]             True       145000        20006
#                           light_poles             [final light poles]             True          910          916
#            fpv_crosswalk_segmentation         [fpv_crosswalk_dataset]            False         6600            0
#                  pedestrian_detection           (flat, no subfolders)            False            0            0
#                   road_sign_detection           [annotations, images]             True          877          877
#                          antic_chairs                  [antic_chairs]            False         1403            0
#                       doors_detection           (flat, no subfolders)            False          208            0
#               indoor_objects_roboflow            [test, train, valid]             True          130          132
#              indoor_detection_vineeth            [test, train, valid]             True         2890         2892
#                  indoor_objects_5iwhq            [test, train, valid]             True         1489         1491
# revised_pedestrian_obstacle_detection                  [train, valid]             True         6342         6344
#                       pedestrian_walk            [test, train, valid]             True         1000         1002
#                       outdoor_objects            [test, train, valid]             True         2400         2402
#                    footpath_detection            [test, train, valid]             True         1687         1689
#                      stairs_detection            [test, train, valid]             True          233          235
#           obstacle_detection_roboflow            [test, train, valid]             True         9183         9185
#             obstacle_detection_kaggle                   [ROD-Dataset]             True        24326        24327
#               indoor_object_detection            [test, train, valid]             True         1349         1342
#                      mapillary_vistas [testing, training, validation]             True       145000        20006
#                           light_poles             [final light poles]             True          910          916
#            fpv_crosswalk_segmentation         [fpv_crosswalk_dataset]            False         6600            0
#                  pedestrian_detection           (flat, no subfolders)            False            0            0
#                   road_sign_detection           [annotations, images]             True          877          877
#                          antic_chairs                  [antic_chairs]            False         1403            0
#                       doors_detection           (flat, no subfolders)            False          208            0
#               indoor_objects_roboflow            [test, train, valid]             True          130          132
#              indoor_detection_vineeth            [test, train, valid]             True         2890         2892
#                  indoor_objects_5iwhq            [test, train, valid]             True         1489         1491
# revised_pedestrian_obstacle_detection                  [train, valid]             True         6342         6344
#                       pedestrian_walk            [test, train, valid]             True         1000         1002
#                       outdoor_objects            [test, train, valid]             True         2400         2402
#                    footpath_detection            [test, train, valid]             True         1687         1689
#                      stairs_detection            [test, train, valid]             True          233          235

# %% [markdown]
# ---
#
# We then do a pairing check
#
# ---

# %%
METADATA_LABEL_FILENAMES = {
    "readme.roboflow.txt", "readme.dataset.txt", "readme.txt",
    "citations.txt", "license.txt", "changelog.txt", "notice.txt"
}

def get_stem_set(folder: Path, exts, exclude_filenames=None):
    exclude_filenames = exclude_filenames or set()
    result = {}
    for f in folder.rglob("*"):
        if f.is_file() and f.suffix.lower() in exts and f.name.lower() not in exclude_filenames:
            result[f.stem] = f
    return result


pairing_results = []
orphan_records = []

corrupt_stems_by_dataset = defaultdict(set)
for issue in file_level_issues:
    p = Path(issue["file"])
    corrupt_stems_by_dataset[issue["dataset"]].add(p.stem)

for row in structure_df.drop_duplicates(subset="dataset").itertuples():
    dataset_name = row.dataset

    if not row.has_label_files:
        pairing_results.append({
            "dataset": dataset_name, "matched": None, "orphan_images": None,
            "orphan_labels": None, "verdict": "NOT_APPLICABLE"
        })
        continue

    if dataset_name == "mapillary_vistas":
        pairing_results.append({
            "dataset": dataset_name, "matched": None, "orphan_images": None,
            "orphan_labels": None, "verdict": "DEFERRED_CUSTOM_CHECK"
        })
        continue

    dataset_path = Path(folder_check_df[folder_check_df["dataset"] == dataset_name]["path"].values[0])

    image_stems = get_stem_set(dataset_path, IMAGE_EXTS)
    label_stems = get_stem_set(dataset_path, {".txt", ".xml"}, exclude_filenames=METADATA_LABEL_FILENAMES)

    corrupt_stems = corrupt_stems_by_dataset.get(dataset_name, set())

    matched = set(image_stems) & set(label_stems)
    matched_clean = matched - corrupt_stems

    orphan_images = set(image_stems) - set(label_stems)
    orphan_labels = set(label_stems) - set(image_stems)

    for stem in orphan_images:
        orphan_records.append({"dataset": dataset_name, "type": "orphan_image", "file": str(image_stems[stem])})
    for stem in orphan_labels:
        orphan_records.append({"dataset": dataset_name, "type": "orphan_label", "file": str(label_stems[stem])})

    logger.info(
        f"[PAIRING] {dataset_name} — matched: {len(matched_clean)}, "
        f"orphan_images: {len(orphan_images)}, orphan_labels: {len(orphan_labels)}"
    )

    pairing_results.append({
        "dataset": dataset_name,
        "matched": len(matched_clean),
        "orphan_images": len(orphan_images),
        "orphan_labels": len(orphan_labels),
        "verdict": "CHECKED"
    })

pairing_df = pd.DataFrame(pairing_results)
print(pairing_df.to_string(index=False))
# Out:
# INFO: [PAIRING] obstacle_detection_roboflow — matched: 9072, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] obstacle_detection_kaggle — matched: 24227, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] indoor_object_detection — matched: 1195, orphan_images: 7, orphan_labels: 0
# INFO: [PAIRING] light_poles — matched: 909, orphan_images: 0, orphan_labels: 7
# INFO: [PAIRING] road_sign_detection — matched: 877, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] indoor_objects_roboflow — matched: 130, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] indoor_detection_vineeth — matched: 2889, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] indoor_objects_5iwhq — matched: 1486, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] revised_pedestrian_obstacle_detection — matched: 6185, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] pedestrian_walk — matched: 1000, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] outdoor_objects — matched: 2361, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] footpath_detection — matched: 1538, orphan_images: 0, orphan_labels: 0
# INFO: [PAIRING] stairs_detection — matched: 229, orphan_images: 0, orphan_labels: 0
#                               dataset  matched  orphan_images  orphan_labels               verdict
#           obstacle_detection_roboflow   9072.0            0.0            0.0               CHECKED
#             obstacle_detection_kaggle  24227.0            0.0            0.0               CHECKED
#               indoor_object_detection   1195.0            7.0            0.0               CHECKED
#                      mapillary_vistas      NaN            NaN            NaN DEFERRED_CUSTOM_CHECK
#                           light_poles    909.0            0.0            7.0               CHECKED
#            fpv_crosswalk_segmentation      NaN            NaN            NaN        NOT_APPLICABLE
#                  pedestrian_detection      NaN            NaN            NaN        NOT_APPLICABLE
#                   road_sign_detection    877.0            0.0            0.0               CHECKED
#                          antic_chairs      NaN            NaN            NaN        NOT_APPLICABLE
#                       doors_detection      NaN            NaN            NaN        NOT_APPLICABLE
#               indoor_objects_roboflow    130.0            0.0            0.0               CHECKED
#              indoor_detection_vineeth   2889.0            0.0            0.0               CHECKED
#                  indoor_objects_5iwhq   1486.0            0.0            0.0               CHECKED
# revised_pedestrian_obstacle_detection   6185.0            0.0            0.0               CHECKED
#                       pedestrian_walk   1000.0            0.0            0.0               CHECKED
#                       outdoor_objects   2361.0            0.0            0.0               CHECKED
#                    footpath_detection   1538.0            0.0            0.0               CHECKED
#                      stairs_detection    229.0            0.0            0.0               CHECKED

# %% [markdown]
# ---
#
# Remove images without label pairs
#
# ---

# %%
orphan_df = pd.DataFrame(orphan_records)
copied_orphans = []

for row in orphan_df.itertuples():
    dataset_name = row.dataset
    src_path = Path(row.file)

    dataset_row = folder_check_df[folder_check_df["dataset"] == dataset_name].iloc[0]
    dataset_raw_root = Path(dataset_row["path"])

    relative_path = src_path.relative_to(dataset_raw_root)
    dest_path = INVALID_DIR / dataset_name / relative_path

    dest_path.parent.mkdir(parents=True, exist_ok=True)

    try:
        shutil.copy2(src_path, dest_path)
        logger.warning(f"[MOVED TO INVALID] {dataset_name} — {relative_path} — reason: {row.type}")
        copied_orphans.append({
            "dataset": dataset_name,
            "file": str(relative_path),
            "reason": row.type,
            "dest": str(dest_path)
        })
    except Exception as e:
        logger.error(f"[COPY FAILED] {dataset_name} — {relative_path} — {e}")

copied_orphans_df = pd.DataFrame(copied_orphans)
print(f"Copied {len(copied_orphans_df)} orphan files into invalid/")
print(copied_orphans_df.groupby(["dataset", "reason"]).size().to_string())
# Out:
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\images\506bd74062053978.jpg — reason: orphan_image
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\images\62fbb8ea21b31940.jpg — reason: orphan_image
# WARNING: [MOVED TO INVALID] indoor_object_detection — test\images\831.png — reason: orphan_image
# WARNING: [MOVED TO INVALID] indoor_object_detection — test\images\1167.png — reason: orphan_image
# WARNING: [MOVED TO INVALID] indoor_object_detection — test\images\1139.png — reason: orphan_image
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\images\acafde3057686f65.jpg — reason: orphan_image
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\images\23e9876d80301685.jpg — reason: orphan_image
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\102-HV-SSU-D-1-CWN-45_DJI_0034-1024_JPG_jpg.rf.dd0b120d7cd1d78b6d3c6d082aac5efc.txt — reason: orphan_label
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\75-PURI-11-SSU-BP-68_DJI_0575-1024_JPG_jpg.rf.79f65ac4ed38abe90d08ff2781346bae.txt — reason: orphan_label
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\342_jpeg_jpg.rf.775547516850ed448decb938d1abf2cc.txt — reason: orphan_label
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\76-MPP-HPH-79-UG-_DJI_0707-1024_JPG_jpg.rf.2da3482af976008b46a0b14140d7aac3.txt — reason: orphan_label
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\73-KGS-PBT-73-J-_DJI_0783-1024_JPG_jpg.rf.7dad5d2965b66e8bbcbc3b6b8d834190.txt — reason: orphan_label
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\69_jpg.rf.d1ca97720848e13786cfb482fa574f25.txt — reason: orphan_label
# WARNING: [MOVED TO INVALID] light_poles — final light poles\labels\image-144_png_jpg.rf.42b671dc340887f20cc9d8eb3ab4eb31.txt — reason: orphan_label
# Copied 14 orphan files into invalid/
# dataset                  reason
# indoor_object_detection  orphan_image    7
# light_poles              orphan_label    7

# %% [markdown]
# ---
#
# This is a custom check for the mapillary dataset
#
# ---

# %%
mapillary_path = Path(folder_check_df[folder_check_df["dataset"] == "mapillary_vistas"]["path"].values[0])

for split in ["training", "validation", "testing"]:
    split_path = mapillary_path / split
    if split_path.exists():
        print(f"\n{split}/ contents:")
        for item in sorted(split_path.iterdir()):
            if item.is_dir():
                file_count = sum(1 for f in item.rglob("*") if f.is_file())
                print(f"  [dir]  {item.name}  ({file_count} files)")
            else:
                print(f"  [file] {item.name}")
    else:
        print(f"\n{split}/ does not exist")

# Also list the top-level json files and any config files
print("\nTop-level files in mapillary_vistas/:")
for item in sorted(mapillary_path.iterdir()):
    if item.is_file():
        print(f"  {item.name}")
# Out:
# training/ contents:
#   [dir]  images  (18000 files)
#   [dir]  v1.2  (54001 files)
#   [dir]  v2.0  (72001 files)
#
# validation/ contents:
#   [dir]  images  (2000 files)
#   [dir]  v1.2  (6001 files)
#   [dir]  v2.0  (8001 files)
#
# testing/ contents:
#   [dir]  images  (5000 files)
#
# Top-level files in mapillary_vistas/:
#   config_v1.2.json
#   config_v2.0.json
#   demo.py
#   LICENSE
#   README

# %% [markdown]
# ---
#
# Check only training and validation folders, skip testing since videos
#
# ---

# %%
mapillary_orphans = []
mapillary_summary = []

def stems_in(folder: Path, ext):
    if not folder.exists():
        return set()
    return {f.stem for f in folder.iterdir() if f.is_file() and f.suffix.lower() == ext}

for split in ["training", "validation"]:
    split_path = mapillary_path / split
    image_stems = stems_in(split_path / "images", ".jpg")

    for version in ["v1.2", "v2.0"]:
        version_path = split_path / version
        if not version_path.exists():
            continue

        for subfolder, ext in [("labels", ".png"), ("instances", ".png"), ("panoptic", ".png")]:
            sub_stems = stems_in(version_path / subfolder, ext)
            missing_in_sub = image_stems - sub_stems
            extra_in_sub = sub_stems - image_stems

            for stem in missing_in_sub:
                mapillary_orphans.append({
                    "split": split, "version": version, "subfolder": subfolder,
                    "type": "image_missing_mask", "stem": stem
                })
            for stem in extra_in_sub:
                mapillary_orphans.append({
                    "split": split, "version": version, "subfolder": subfolder,
                    "type": "mask_missing_image", "stem": stem
                })

            mapillary_summary.append({
                "split": split, "version": version, "subfolder": subfolder,
                "images": len(image_stems), "masks": len(sub_stems),
                "missing_masks": len(missing_in_sub), "orphan_masks": len(extra_in_sub)
            })

        # v2.0 also has polygons/ (json, not png)
        if version == "v2.0":
            poly_stems = stems_in(version_path / "polygons", ".json")
            missing_poly = image_stems - poly_stems
            extra_poly = poly_stems - image_stems

            for stem in missing_poly:
                mapillary_orphans.append({
                    "split": split, "version": version, "subfolder": "polygons",
                    "type": "image_missing_mask", "stem": stem
                })
            for stem in extra_poly:
                mapillary_orphans.append({
                    "split": split, "version": version, "subfolder": "polygons",
                    "type": "mask_missing_image", "stem": stem
                })

            mapillary_summary.append({
                "split": split, "version": version, "subfolder": "polygons",
                "images": len(image_stems), "masks": len(poly_stems),
                "missing_masks": len(missing_poly), "orphan_masks": len(extra_poly)
            })

mapillary_summary_df = pd.DataFrame(mapillary_summary)
print(mapillary_summary_df.to_string(index=False))

logger.info(f"[MAPILLARY PAIRING] Checked training/validation across v1.2 and v2.0. "
            f"Total orphan records: {len(mapillary_orphans)}")
# Out:
# INFO: [MAPILLARY PAIRING] Checked training/validation across v1.2 and v2.0. Total orphan records: 0
#      split version subfolder  images  masks  missing_masks  orphan_masks
#   training    v1.2    labels   18000  18000              0             0
#   training    v1.2 instances   18000  18000              0             0
#   training    v1.2  panoptic   18000  18000              0             0
#   training    v2.0    labels   18000  18000              0             0
#   training    v2.0 instances   18000  18000              0             0
#   training    v2.0  panoptic   18000  18000              0             0
#   training    v2.0  polygons   18000  18000              0             0
# validation    v1.2    labels    2000   2000              0             0
# validation    v1.2 instances    2000   2000              0             0
# validation    v1.2  panoptic    2000   2000              0             0
# validation    v2.0    labels    2000   2000              0             0
# validation    v2.0 instances    2000   2000              0             0
# validation    v2.0  panoptic    2000   2000              0             0
# validation    v2.0  polygons    2000   2000              0             0

# %% [markdown]
# ---
#
# Annotation check across all dataset
#
# ---

# %%
roboflow_datasets = [
    "obstacle_detection_roboflow", "indoor_objects_roboflow", "indoor_detection_vineeth",
    "indoor_objects_5iwhq", "revised_pedestrian_obstacle_detection", "pedestrian_walk",
    "outdoor_objects", "footpath_detection", "stairs_detection"
]

dataset_class_info = {}  # {dataset_name: {"num_classes": int, "names": [...]}}

for dataset_name in roboflow_datasets:
    dataset_path = Path(folder_check_df[folder_check_df["dataset"] == dataset_name]["path"].values[0])
    yaml_candidates = list(dataset_path.glob("*.yaml")) + list(dataset_path.glob("**/data.yaml"))

    if not yaml_candidates:
        logger.warning(f"[CLASS INFO] {dataset_name} — no data.yaml found.")
        continue

    yaml_path = yaml_candidates[0]
    try:
        with open(yaml_path, "r", encoding="utf-8") as f:
            data_yaml = yaml.safe_load(f)

        names = data_yaml.get("names")
        num_classes = data_yaml.get("nc", len(names) if names else None)

        dataset_class_info[dataset_name] = {"num_classes": num_classes, "names": names}
        logger.info(f"[CLASS INFO] {dataset_name} — {num_classes} classes: {names}")

    except Exception as e:
        logger.error(f"[CLASS INFO FAILED] {dataset_name} — {yaml_path} — {e}")

for name, info in dataset_class_info.items():
    print(f"{name}: {info['num_classes']} classes — {info['names']}")
# Out:
# INFO: [CLASS INFO] obstacle_detection_roboflow — 10 classes: ['Bicycle', 'Bus', 'Car', 'Dog', 'Electric pole', 'Motorcycle', 'Person', 'Traffic signs', 'Tree', 'Uncovered manhole']
# INFO: [CLASS INFO] indoor_objects_roboflow — 125 classes: ['-m-0130jx', '-m-014sv8', '-m-015p6', '-m-0174k2', '-m-018xm', '-m-0199g', '-m-019dx1', '-m-01_bhs', '-m-01bqk0', '-m-01c648', '-m-01d40f', '-m-01dxs', '-m-01g317', '-m-01jfm_', '-m-01jfsr', '-m-01lcw4', '-m-01lynh', '-m-01mzpv', '-m-01prls', '-m-01s105', '-m-01s55n', '-m-01ww8y', '-m-01y9k5', '-m-021sj1', '-m-02522', '-m-025dyy', '-m-026qbn5', '-m-0283dt1', '-m-029bxz', '-m-02crq1', '-m-02cvgx', '-m-02dgv', '-m-02jz0l', '-m-02p0tk3', '-m-02pkr5', '-m-02s195', '-m-02w3r3', '-m-02wbm', '-m-02wv84t', '-m-02xwb', '-m-02z51p', '-m-031n1', '-m-034c16', '-m-035r7c', '-m-039xj_', '-m-03__z0', '-m-03bt1vf', '-m-03c7gz', '-m-03fp41', '-m-03jm5', '-m-03m3pdh', '-m-03q69', '-m-03rszm', '-m-03ssj5', '-m-03tw93', '-m-03vt0', '-m-040b_t', '-m-04169hn', '-m-0463sg', '-m-04bcr3', '-m-04brg2', '-m-04dr76w', '-m-04hgtk', '-m-04p0qw', '-m-04rky', '-m-04szw', '-m-04y4h8h', '-m-04yx4', '-m-052sf', '-m-057cc', '-m-05_5p_0', '-m-05kyg_', '-m-05n4y', '-m-05r5c', '-m-05r655', '-m-05s2s', '-m-05y5lj', '-m-05zsy', '-m-0642b4', '-m-06msq', '-m-0703r8', '-m-078n6m', '-m-07c52', '-m-07j7r', '-m-07yv9', '-m-083wq', '-m-09b5t', '-m-09g1w', '-m-09j2d', '-m-09j5n', '-m-09qck', '-m-0b3fp9', '-m-0b_rs', '-m-0bt9lr', '-m-0bt_c3', '-m-0c9ph5', '-m-0c_jw', '-m-0cgh4', '-m-0crjs', '-m-0cvnqh', '-m-0cyf8', '-m-0d4v4', '-m-0dtln', '-m-0dv9c', '-m-0dzct', '-m-0dzf4', '-m-0fly7', '-m-0fm3zh', '-m-0fqfqc', '-m-0fqt361', '-m-0fx9l', '-m-0gjbg72', '-m-0h2r6', '-m-0h8n5zk', '-m-0h8n6f9', '-m-0h8nr_l', '-m-0h99cwc', '-m-0hg7b', '-m-0jbk', '-m-0jqgx', '-m-0k0pj', '-m-0k4j', '-m-0k65p', '-m-0kpqd', '-m-0qmmr']
# INFO: [CLASS INFO] indoor_detection_vineeth — 10 classes: ['cabinet', 'cabinetDoor', 'chair', 'couch', 'door', 'openedDoor', 'pole', 'refrigeratorDoor', 'table', 'window']
# INFO: [CLASS INFO] indoor_objects_5iwhq — 10 classes: ['bed', 'chair', 'door', 'door-frame', 'shower', 'sink', 'sofa', 'stairs', 'table', 'toilet']
# INFO: [CLASS INFO] revised_pedestrian_obstacle_detection — 7 classes: ['animal', 'bike', 'crosswalk', 'hazard-sign', 'person', 'stairs', 'vehicle']
# INFO: [CLASS INFO] pedestrian_walk — 3 classes: ['B', 'F', 'M']
# INFO: [CLASS INFO] outdoor_objects — 7 classes: ['building', 'foot path', 'person', 'plants', 'road', 'street light', 'trees']
# INFO: [CLASS INFO] footpath_detection — 5 classes: ['obstacle_1', 'obstacle_2', 'person_back', 'person_front', 'vehicle']
# INFO: [CLASS INFO] stairs_detection — 1 classes: ['stairs']
# obstacle_detection_roboflow: 10 classes — ['Bicycle', 'Bus', 'Car', 'Dog', 'Electric pole', 'Motorcycle', 'Person', 'Traffic signs', 'Tree', 'Uncovered manhole']
# indoor_objects_roboflow: 125 classes — ['-m-0130jx', '-m-014sv8', '-m-015p6', '-m-0174k2', '-m-018xm', '-m-0199g', '-m-019dx1', '-m-01_bhs', '-m-01bqk0', '-m-01c648', '-m-01d40f', '-m-01dxs', '-m-01g317', '-m-01jfm_', '-m-01jfsr', '-m-01lcw4', '-m-01lynh', '-m-01mzpv', '-m-01prls', '-m-01s105', '-m-01s55n', '-m-01ww8y', '-m-01y9k5', '-m-021sj1', '-m-02522', '-m-025dyy', '-m-026qbn5', '-m-0283dt1', '-m-029bxz', '-m-02crq1', '-m-02cvgx', '-m-02dgv', '-m-02jz0l', '-m-02p0tk3', '-m-02pkr5', '-m-02s195', '-m-02w3r3', '-m-02wbm', '-m-02wv84t', '-m-02xwb', '-m-02z51p', '-m-031n1', '-m-034c16', '-m-035r7c', '-m-039xj_', '-m-03__z0', '-m-03bt1vf', '-m-03c7gz', '-m-03fp41', '-m-03jm5', '-m-03m3pdh', '-m-03q69', '-m-03rszm', '-m-03ssj5', '-m-03tw93', '-m-03vt0', '-m-040b_t', '-m-04169hn', '-m-0463sg', '-m-04bcr3', '-m-04brg2', '-m-04dr76w', '-m-04hgtk', '-m-04p0qw', '-m-04rky', '-m-04szw', '-m-04y4h8h', '-m-04yx4', '-m-052sf', '-m-057cc', '-m-05_5p_0', '-m-05kyg_', '-m-05n4y', '-m-05r5c', '-m-05r655', '-m-05s2s', '-m-05y5lj', '-m-05zsy', '-m-0642b4', '-m-06msq', '-m-0703r8', '-m-078n6m', '-m-07c52', '-m-07j7r', '-m-07yv9', '-m-083wq', '-m-09b5t', '-m-09g1w', '-m-09j2d', '-m-09j5n', '-m-09qck', '-m-0b3fp9', '-m-0b_rs', '-m-0bt9lr', '-m-0bt_c3', '-m-0c9ph5', '-m-0c_jw', '-m-0cgh4', '-m-0crjs', '-m-0cvnqh', '-m-0cyf8', '-m-0d4v4', '-m-0dtln', '-m-0dv9c', '-m-0dzct', '-m-0dzf4', '-m-0fly7', '-m-0fm3zh', '-m-0fqfqc', '-m-0fqt361', '-m-0fx9l', '-m-0gjbg72', '-m-0h2r6', '-m-0h8n5zk', '-m-0h8n6f9', '-m-0h8nr_l', '-m-0h99cwc', '-m-0hg7b', '-m-0jbk', '-m-0jqgx', '-m-0k0pj', '-m-0k4j', '-m-0k65p', '-m-0kpqd', '-m-0qmmr']
# indoor_detection_vineeth: 10 classes — ['cabinet', 'cabinetDoor', 'chair', 'couch', 'door', 'openedDoor', 'pole', 'refrigeratorDoor', 'table', 'window']
# indoor_objects_5iwhq: 10 classes — ['bed', 'chair', 'door', 'door-frame', 'shower', 'sink', 'sofa', 'stairs', 'table', 'toilet']
# revised_pedestrian_obstacle_detection: 7 classes — ['animal', 'bike', 'crosswalk', 'hazard-sign', 'person', 'stairs', 'vehicle']
# pedestrian_walk: 3 classes — ['B', 'F', 'M']
# outdoor_objects: 7 classes — ['building', 'foot path', 'person', 'plants', 'road', 'street light', 'trees']
# footpath_detection: 5 classes — ['obstacle_1', 'obstacle_2', 'person_back', 'person_front', 'vehicle']
# stairs_detection: 1 classes — ['stairs']

# %%
# --- Fixed YOLO checker (bbox + polygon support) ---
def check_yolo_txt(filepath: Path, num_classes=None):
    issues = []
    try:
        with open(filepath, "r", encoding="utf-8") as f:
            lines = [ln.strip() for ln in f if ln.strip()]
    except Exception as e:
        return [f"unreadable: {e}"]

    if not lines:
        return []

    for i, line in enumerate(lines):
        parts = line.split()
        n = len(parts)

        try:
            class_id = int(float(parts[0]))
        except (ValueError, IndexError):
            issues.append(f"line {i}: non-numeric or missing class_id")
            continue

        if class_id < 0:
            issues.append(f"line {i}: negative class_id {class_id}")
        if num_classes is not None and class_id >= num_classes:
            issues.append(f"line {i}: class_id {class_id} out of range (max {num_classes - 1})")

        coord_values = parts[1:]

        if n == 5:
            try:
                x, y, w, h = (float(v) for v in coord_values)
            except ValueError:
                issues.append(f"line {i}: non-numeric bbox value")
                continue
            if not (0 <= x <= 1 and 0 <= y <= 1):
                issues.append(f"line {i}: center out of bounds ({x}, {y})")
            if not (0 < w <= 1 and 0 < h <= 1):
                issues.append(f"line {i}: invalid width/height ({w}, {h})")

        elif n >= 7 and n % 2 == 1:
            try:
                coords = [float(v) for v in coord_values]
            except ValueError:
                issues.append(f"line {i}: non-numeric polygon coordinate")
                continue
            out_of_bounds = [c for c in coords if not (0 <= c <= 1)]
            if out_of_bounds:
                issues.append(f"line {i}: {len(out_of_bounds)} polygon coordinate(s) out of 0-1 bounds")

        else:
            issues.append(f"line {i}: unexpected field count {n} (not bbox-5 or valid polygon)")

    return issues


# --- Re-run annotation check with console logging silenced ---
annotation_issues = []
annotation_summary = []

stream_handler.setLevel(logging.CRITICAL)  # <-- silence console, file logging still works

try:
    for row in structure_df.drop_duplicates(subset="dataset").itertuples():
        dataset_name = row.dataset

        if not row.has_label_files or dataset_name == "mapillary_vistas":
            continue

        dataset_path = Path(folder_check_df[folder_check_df["dataset"] == dataset_name]["path"].values[0])
        class_info = dataset_class_info.get(dataset_name)
        num_classes = class_info["num_classes"] if class_info else None

        label_files = [f for f in dataset_path.rglob("*")
                       if f.is_file() and f.suffix.lower() in {".txt", ".xml"}
                       and f.name.lower() not in METADATA_LABEL_FILENAMES]

        clean_count = 0
        bad_count = 0

        for f in tqdm(label_files, desc=dataset_name, leave=False):
            if f.suffix.lower() == ".txt":
                issues = check_yolo_txt(f, num_classes=num_classes)
            else:
                issues = check_voc_xml(f)

            if issues:
                bad_count += 1
                for issue in issues:
                    annotation_issues.append({"dataset": dataset_name, "file": str(f), "issue": issue})
                logger.warning(f"[BAD ANNOTATION] {dataset_name} — {f.name} — {issues[0]}")
            else:
                clean_count += 1

        logger.info(f"[ANNOTATION CHECK] {dataset_name} — clean: {clean_count}, bad: {bad_count}")

        annotation_summary.append({
            "dataset": dataset_name,
            "total_labels": len(label_files),
            "clean": clean_count,
            "bad": bad_count,
            "class_range_checked": num_classes is not None
        })

finally:
    stream_handler.setLevel(logging.INFO)  # <-- always restore, even if something errors

annotation_summary_df = pd.DataFrame(annotation_summary)
print(annotation_summary_df.to_string(index=False))
# Out:
#                               dataset  total_labels  clean  bad  class_range_checked
#           obstacle_detection_roboflow          9183   9182    1                 True
#             obstacle_detection_kaggle         24326  24326    0                False
#               indoor_object_detection          1342   1340    2                False
#                           light_poles           916    916    0                False
#                   road_sign_detection           877    877    0                False
#               indoor_objects_roboflow           130    130    0                 True
#              indoor_detection_vineeth          2890   2890    0                 True
#                  indoor_objects_5iwhq          1489   1489    0                 True
# revised_pedestrian_obstacle_detection          6342   6342    0                 True
#                       pedestrian_walk          1000   1000    0                 True
#                       outdoor_objects          2400   2400    0                 True
#                    footpath_detection          1687   1687    0                 True
#                      stairs_detection           233    233    0                 True

# %% [markdown]
# ---
#
# Inspect found issues
#
# ---

# %%
issues_df = pd.DataFrame(annotation_issues)
print(issues_df.to_string(index=False))
# Out:
#                     dataset                                                                                                                                                     file                                             issue
# obstacle_detection_roboflow D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\roboflow\obstacle_detection_roboflow\train\labels\img-3622_jpeg.rf.9b7c281610b6e946170e7255c80e51b0.txt line 0: 7 polygon coordinate(s) out of 0-1 bounds
#     indoor_object_detection                                        D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\indoor_object_detection\train\labels\0c30772b7ea51745.txt      line 5: invalid width/height (0.000977, 0.0)
#     indoor_object_detection                                        D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\raw\kaggle\indoor_object_detection\train\labels\a30d502fade25820.txt           line 0: invalid width/height (0.0, 0.0)

# %% [markdown]
# ---
#
# Remove those issues along with their pictures (only use when the number is not too big)
#
# ---

# %%
# --- Step: Copy files with bad annotation content into invalid/ (whole file + paired image) ---

bad_annotation_df = pd.DataFrame(annotation_issues)
# One row per unique bad label file (a file might have multiple bad lines, only need to handle it once)
bad_label_files = bad_annotation_df.drop_duplicates(subset=["dataset", "file"])

copied_bad_annotations = []

for row in bad_label_files.itertuples():
    dataset_name = row.dataset
    label_path = Path(row.file)

    dataset_row = folder_check_df[folder_check_df["dataset"] == dataset_name].iloc[0]
    dataset_raw_root = Path(dataset_row["path"])

    # Copy the bad label file itself
    relative_label_path = label_path.relative_to(dataset_raw_root)
    dest_label_path = INVALID_DIR / dataset_name / relative_label_path
    dest_label_path.parent.mkdir(parents=True, exist_ok=True)

    try:
        shutil.copy2(label_path, dest_label_path)
        logger.warning(f"[MOVED TO INVALID] {dataset_name} — {relative_label_path} — reason: bad annotation content")
        copied_bad_annotations.append({
            "dataset": dataset_name, "file": str(relative_label_path),
            "type": "label", "reason": "bad annotation content"
        })
    except Exception as e:
        logger.error(f"[COPY FAILED] {dataset_name} — {relative_label_path} — {e}")

    # Find and copy the paired image (same stem, look in IMAGE_EXTS within the same dataset)
    stem = label_path.stem
    matching_images = [f for f in dataset_raw_root.rglob(f"{stem}.*") if f.suffix.lower() in IMAGE_EXTS]

    for img_path in matching_images:
        relative_img_path = img_path.relative_to(dataset_raw_root)
        dest_img_path = INVALID_DIR / dataset_name / relative_img_path
        dest_img_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            shutil.copy2(img_path, dest_img_path)
            logger.warning(f"[MOVED TO INVALID] {dataset_name} — {relative_img_path} — reason: paired label has bad annotation content")
            copied_bad_annotations.append({
                "dataset": dataset_name, "file": str(relative_img_path),
                "type": "image", "reason": "paired label has bad annotation content"
            })
        except Exception as e:
            logger.error(f"[COPY FAILED] {dataset_name} — {relative_img_path} — {e}")

copied_bad_annotations_df = pd.DataFrame(copied_bad_annotations)
print(f"Copied {len(copied_bad_annotations_df)} files (labels + paired images) into invalid/")
print(copied_bad_annotations_df.groupby(["dataset", "type"]).size().to_string())
# Out:
# WARNING: [MOVED TO INVALID] obstacle_detection_roboflow — train\labels\img-3622_jpeg.rf.9b7c281610b6e946170e7255c80e51b0.txt — reason: bad annotation content
# WARNING: [MOVED TO INVALID] obstacle_detection_roboflow — train\images\img-3622_jpeg.rf.9b7c281610b6e946170e7255c80e51b0.jpg — reason: paired label has bad annotation content
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\labels\0c30772b7ea51745.txt — reason: bad annotation content
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\images\0c30772b7ea51745.jpg — reason: paired label has bad annotation content
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\labels\a30d502fade25820.txt — reason: bad annotation content
# WARNING: [MOVED TO INVALID] indoor_object_detection — train\images\a30d502fade25820.jpg — reason: paired label has bad annotation content
# Copied 6 files (labels + paired images) into invalid/
# dataset                      type
# indoor_object_detection      image    2
#                              label    2
# obstacle_detection_roboflow  image    1
#                              label    1

# %% [markdown]
# ---
#
# Inspect the mapillary structure again
#
# ---

# %%
import json

# Inspect one panoptic JSON file structure
panoptic_json_path = mapillary_path / "training" / "v2.0" / "panoptic" / "panoptic_2020.json"

with open(panoptic_json_path, "r", encoding="utf-8") as f:
    panoptic_data = json.load(f)

print("Top-level keys:", list(panoptic_data.keys()))
print("\nNumber of annotations:", len(panoptic_data.get("annotations", [])))
print("Number of categories:", len(panoptic_data.get("categories", [])))
print("\nSample annotation entry:")
print(json.dumps(panoptic_data["annotations"][0], indent=2)[:1000])
print("\nSample category entry:")
print(json.dumps(panoptic_data["categories"][0], indent=2))
# Out:
# Top-level keys: ['annotations', 'categories', 'images', 'info']
#
# Number of annotations: 18000
# Number of categories: 116
#
# Sample annotation entry:
# {
#   "image_id": "79YI0cAP3hU_YjnxabEoZQ",
#   "file_name": "79YI0cAP3hU_YjnxabEoZQ.png",
#   "segments_info": [
#     {
#       "id": 1,
#       "category_id": 59,
#       "area": 3050863,
#       "bbox": [
#         0,
#         0,
#         3999,
#         1389
#       ],
#       "iscrowd": 0
#     },
#     {
#       "id": 2,
#       "category_id": 21,
#       "area": 421537,
#       "bbox": [
#         1648,
#         1597,
#         2351,
#         661
#       ],
#       "iscrowd": 0
#     },
#     {
#       "id": 3,
#       "category_id": 43,
#       "area": 3940644,
#       "bbox": [
#         0,
#         1837,
#         3999,
#         1162
#       ],
#       "iscrowd": 0
#     },
#     {
#       "id": 4,
#       "category_id": 27,
#       "area": 1073837,
#       "bbox": [
#         0,
#         327,
#         3999,
#         1296
#       ],
#       "iscrowd": 0
#     },
#     {
#       "id": 5,
#       "category_id": 80,
#       "area": 257881,
#       "bbox": [
#         444,
#         419,
#         975,
#         668
#       ],
#       "iscrowd": 0
#     },
#     {
#       "id": 6,
#       "category_
#
# Sample category entry:
# {
#   "id": 1,
#   "name": "animal--bird",
#   "supercategory": "animal",
#   "isthing": 1,
#   "color": [
#     165,
#     42,
#     42
#   ]
# }

# %% [markdown]
# ---
#
# The mapillary annotation check (I hate whoever gave me this)
#
# ---

# %%
# --- Step: Validate mapillary_vistas panoptic JSON content ---

mapillary_json_issues = []
mapillary_json_summary = []

def check_panoptic_json(json_path: Path, split_path: Path, version: str, split: str):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    images = data.get("images", [])
    annotations = data.get("annotations", [])
    categories = data.get("categories", [])

    valid_category_ids = {c["id"] for c in categories}
    image_ids_in_json = {img["id"] for img in images}
    image_filenames_in_json = {img["file_name"] for img in images}

    # What actually exists on disk
    actual_image_files = {f.name for f in (split_path / "images").glob("*.jpg")}

    issues = []

    # 1. Every image entry's file_name should exist on disk
    missing_on_disk = image_filenames_in_json - actual_image_files
    for fname in missing_on_disk:
        issues.append({"type": "image_listed_but_missing_on_disk", "file": fname})

    # 2. Every actual image file should be listed in the JSON
    unlisted_files = actual_image_files - image_filenames_in_json
    for fname in unlisted_files:
        issues.append({"type": "image_on_disk_but_not_in_json", "file": fname})

    # 3. Every annotation's image_id should correspond to a real image entry
    annotation_image_ids = {a["image_id"] for a in annotations}
    orphan_annotations = annotation_image_ids - image_ids_in_json
    for img_id in orphan_annotations:
        issues.append({"type": "annotation_references_unknown_image_id", "file": img_id})

    # 4. Every image should have exactly one annotation entry
    images_without_annotation = image_ids_in_json - annotation_image_ids
    for img_id in images_without_annotation:
        issues.append({"type": "image_has_no_annotation_entry", "file": img_id})

    # 5. Every category_id used inside segments_info should exist in categories
    bad_category_refs = 0
    bad_bbox_count = 0
    for ann in annotations:
        for seg in ann.get("segments_info", []):
            if seg["category_id"] not in valid_category_ids:
                bad_category_refs += 1
                issues.append({
                    "type": "invalid_category_id",
                    "file": f"{ann['image_id']} segment {seg['id']} category {seg['category_id']}"
                })
            bbox = seg.get("bbox", [])
            if len(bbox) == 4:
                x, y, w, h = bbox
                if w <= 0 or h <= 0 or x < 0 or y < 0:
                    bad_bbox_count += 1
                    issues.append({
                        "type": "invalid_segment_bbox",
                        "file": f"{ann['image_id']} segment {seg['id']}"
                    })

    for issue in issues:
        mapillary_json_issues.append({
            "split": split, "version": version, **issue
        })

    mapillary_json_summary.append({
        "split": split, "version": version,
        "total_images": len(images), "total_annotations": len(annotations),
        "missing_on_disk": len(missing_on_disk),
        "unlisted_files": len(unlisted_files),
        "orphan_annotations": len(orphan_annotations),
        "images_without_annotation": len(images_without_annotation),
        "invalid_category_refs": bad_category_refs,
        "invalid_bboxes": bad_bbox_count
    })


json_files_to_check = [
    ("training", "v1.2", mapillary_path / "training" / "v1.2" / "panoptic" / "panoptic_2018.json"),
    ("training", "v2.0", mapillary_path / "training" / "v2.0" / "panoptic" / "panoptic_2020.json"),
    ("validation", "v1.2", mapillary_path / "validation" / "v1.2" / "panoptic" / "panoptic_2018.json"),
    ("validation", "v2.0", mapillary_path / "validation" / "v2.0" / "panoptic" / "panoptic_2020.json"),
]

stream_handler.setLevel(logging.CRITICAL)
try:
    for split, version, json_path in json_files_to_check:
        if json_path.exists():
            check_panoptic_json(json_path, mapillary_path / split, version, split)
        else:
            logger.warning(f"[MAPILLARY JSON] Missing expected file: {json_path}")
finally:
    stream_handler.setLevel(logging.INFO)

mapillary_json_summary_df = pd.DataFrame(mapillary_json_summary)
print(mapillary_json_summary_df.to_string(index=False))
# Out:
#      split version  total_images  total_annotations  missing_on_disk  unlisted_files  orphan_annotations  images_without_annotation  invalid_category_refs  invalid_bboxes
#   training    v1.2         18000              18000                0               0                   0                          0                      0               0
#   training    v2.0         18000              18000                0               0                   0                          0                      0             945
# validation    v1.2          2000               2000                0               0                   0                          0                      0               0
# validation    v2.0          2000               2000                0               0                   0                          0                      0             111

# %% [markdown]
# ---
#
# Inspect bboxes issue
#
# ---

# %%
# --- Inspect actual invalid bbox entries ---
bbox_issues_df = pd.DataFrame(mapillary_json_issues)
bbox_only = bbox_issues_df[bbox_issues_df["type"] == "invalid_segment_bbox"]

print("Sample invalid bbox issues:")
print(bbox_only.head(10).to_string(index=False))

# Let's pull up the actual segment data for a couple of these to see the real bbox values
with open(mapillary_path / "training" / "v2.0" / "panoptic" / "panoptic_2020.json", "r", encoding="utf-8") as f:
    v2_data = json.load(f)

# Grab the first flagged image_id and inspect its segments
first_bad = bbox_only.iloc[0]["file"].split(" segment ")[0]
matching_ann = next(a for a in v2_data["annotations"] if a["image_id"] == first_bad)

print(f"\nFull segments_info for image_id {first_bad}:")
for seg in matching_ann["segments_info"]:
    print(seg)
# Out:
# Sample invalid bbox issues:
#    split version                 type                              file
# training    v2.0 invalid_segment_bbox 79YI0cAP3hU_YjnxabEoZQ segment 14
# training    v2.0 invalid_segment_bbox ath8AkxtfH6mHJeo48rPAg segment 10
# training    v2.0 invalid_segment_bbox 42_s6bc6KPMg--ovX2T4hQ segment 80
# training    v2.0 invalid_segment_bbox WCxJL0swuzLMkmV7imHkhQ segment 42
# training    v2.0 invalid_segment_bbox  _ahwYra-74r_e0BLtu9Lfw segment 2
# training    v2.0 invalid_segment_bbox VTn3dZebQaOZ5T9hoXdQCQ segment 28
# training    v2.0 invalid_segment_bbox 2hjcrGPPRq8irEsY2u-z5Q segment 64
# training    v2.0 invalid_segment_bbox EUUNQM1t-jgy53YIvWE1dA segment 30
# {'id': 53, 'category_id': 82, 'area': 4871, 'bbox': [2912, 908, 25, 388], 'iscrowd': 0}

# %% [markdown]
# ---
#
# These zero-area bboxes come from tiny (often 1-pixel) panoptic segments, not corrupted data — this code logs them for the record but doesn't treat them as invalid, so the images and their annotations still go into validated
#
# ---

# %%
# --- Reclassify tiny/zero-area bboxes as informational, not invalid ---

bbox_issues = [i for i in mapillary_json_issues if i["type"] == "invalid_segment_bbox"]

logger.info(
    f"[MAPILLARY BBOX] {len(bbox_issues)} segments flagged with zero/near-zero area bbox "
    f"across v2.0 (training + validation). These are sub-pixel panoptic boundary artifacts, "
    f"not treated as validation failures — images and their annotations remain in the "
    f"validated pipeline. See validation_log for full list if needed."
)

print(f"{len(bbox_issues)} zero-area bbox segments noted as informational (not invalid).")
print("These images and annotations will proceed to validated/ normally.")
# Out:
# INFO: [MAPILLARY BBOX] 1056 segments flagged with zero/near-zero area bbox across v2.0 (training + validation). These are sub-pixel panoptic boundary artifacts, not treated as validation failures — images and their annotations remain in the validated pipeline. See validation_log for full list if needed.
# 1056 zero-area bbox segments noted as informational (not invalid).
# These images and annotations will proceed to validated/ normally.

# %% [markdown]
# ---
#
# We now check for duplication, only within each dataset, cross checking on large scale will be done when merging
#
# ---

# %%
# --- Step: Exact duplicate detection, within each dataset ---

def hash_file(filepath: Path, chunk_size=8192):
    """Compute MD5 hash of a file's contents."""
    hasher = hashlib.md5()
    with open(filepath, "rb") as f:
        while chunk := f.read(chunk_size):
            hasher.update(chunk)
    return hasher.hexdigest()


duplicate_results = []
duplicate_records = []  # every individual duplicate file, for the report

stream_handler.setLevel(logging.CRITICAL)
try:
    for row in folder_check_df.itertuples():
        if row.verdict != "OK":
            continue

        dataset_name = row.dataset
        dataset_path = Path(row.path)

        # Only hash actual data files — skip metadata (README, yaml, etc.)
        all_files = [f for f in dataset_path.rglob("*")
                     if f.is_file() and f.name.lower() not in METADATA_LABEL_FILENAMES
                     and f.suffix.lower() not in METADATA_EXTS]

        hash_to_files = defaultdict(list)

        for f in tqdm(all_files, desc=dataset_name, leave=False):
            try:
                file_hash = hash_file(f)
                hash_to_files[file_hash].append(f)
            except Exception as e:
                logger.error(f"[HASH FAILED] {dataset_name} — {f} — {e}")

        # Any hash with more than 1 file = duplicates
        dup_groups = {h: files for h, files in hash_to_files.items() if len(files) > 1}
        total_dup_files = sum(len(files) - 1 for files in dup_groups.values())  # extras, keeping 1 as "original"

        for file_hash, files in dup_groups.items():
            # Keep the first one (by path sort) as "original", rest are duplicates
            sorted_files = sorted(files)
            original = sorted_files[0]
            for dup in sorted_files[1:]:
                duplicate_records.append({
                    "dataset": dataset_name,
                    "original": str(original),
                    "duplicate": str(dup),
                    "hash": file_hash
                })
                logger.warning(f"[DUPLICATE] {dataset_name} — {dup} — duplicate of {original}")

        logger.info(f"[DUPLICATE CHECK] {dataset_name} — total files: {len(all_files)}, "
                    f"duplicate groups: {len(dup_groups)}, extra duplicate files: {total_dup_files}")

        duplicate_results.append({
            "dataset": dataset_name,
            "total_files_checked": len(all_files),
            "duplicate_groups": len(dup_groups),
            "extra_duplicate_files": total_dup_files
        })
finally:
    stream_handler.setLevel(logging.INFO)

duplicate_summary_df = pd.DataFrame(duplicate_results)
print(duplicate_summary_df.to_string(index=False))
# Out:
#                               dataset  total_files_checked  duplicate_groups  extra_duplicate_files
#           obstacle_detection_roboflow                18366               107                    216
#             obstacle_detection_kaggle                48655              2443                   4370
#               indoor_object_detection                 2691                 2                    147
#                      mapillary_vistas               165008                 0                      0
#                           light_poles                 1826                 2                      2
#            fpv_crosswalk_segmentation                 6600                 0                      0
#                  pedestrian_detection                    6                 0                      0
#                   road_sign_detection                 1754                 2                      2
#                          antic_chairs                 1403                13                     13
#                       doors_detection                  208                 0                      0
#               indoor_objects_roboflow                  260                 0                      0
#              indoor_detection_vineeth                 5780                 2                     24
#                  indoor_objects_5iwhq                 2978                14                     15
# revised_pedestrian_obstacle_detection                12684              1286                   1490
#                       pedestrian_walk                 2000               168                    236
#                       outdoor_objects                 4800               730                   1510
#                    footpath_detection                 3374               425                    659
#                      stairs_detection                  466                 5                     11

# %% [markdown]
# ---
#
# Mark files for removal
#
# ---

# %%
# --- Step: Resolve cross-split duplicates in obstacle_detection_kaggle ---
# Rule: keep the copy in 'train' if one exists; otherwise keep 'test' over 'valid' (arbitrary tiebreak)

split_priority = {"train": 0, "test": 1, "valid": 2}  # lower number = higher priority to KEEP

cross_split_dups = kaggle_dups[kaggle_dups["cross_split"]].copy()

removed_for_leakage = []

for row in cross_split_dups.itertuples():
    orig_path = Path(row.original)
    dup_path = Path(row.duplicate)

    orig_priority = split_priority.get(row.original_split, 99)
    dup_priority = split_priority.get(row.duplicate_split, 99)

    # The one with LOWER priority number gets kept; the other gets removed (copied to invalid, not deleted from raw)
    if orig_priority <= dup_priority:
        keep, remove = orig_path, dup_path
    else:
        keep, remove = dup_path, orig_path

    removed_for_leakage.append({
        "dataset": "obstacle_detection_kaggle",
        "kept": str(keep),
        "removed": str(remove),
        "reason": "cross-split duplicate (data leakage risk)"
    })

removed_df = pd.DataFrame(removed_for_leakage).drop_duplicates(subset="removed")
print(f"Files to remove from validated pool due to cross-split leakage: {len(removed_df)}")
print(removed_df["removed"].apply(lambda p: get_split(p)).value_counts())
# Out:
# Files to remove from validated pool due to cross-split leakage: 574
# removed
# valid    444
# test     130
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# Copy those into invalid
#
# ---

# %%
# --- Step: Copy cross-split duplicate images + paired labels into invalid/ ---

dataset_raw_root = Path(folder_check_df[folder_check_df["dataset"] == "obstacle_detection_kaggle"]["path"].values[0])

copied_leakage = []

for row in removed_df.itertuples():
    img_path = Path(row.removed)

    # Copy the duplicate image itself
    relative_img_path = img_path.relative_to(dataset_raw_root)
    dest_img_path = INVALID_DIR / "obstacle_detection_kaggle" / relative_img_path
    dest_img_path.parent.mkdir(parents=True, exist_ok=True)

    try:
        shutil.copy2(img_path, dest_img_path)
        logger.warning(f"[MOVED TO INVALID] obstacle_detection_kaggle — {relative_img_path} — reason: cross-split duplicate")
        copied_leakage.append({"file": str(relative_img_path), "type": "image"})
    except Exception as e:
        logger.error(f"[COPY FAILED] obstacle_detection_kaggle — {relative_img_path} — {e}")

    # Find and copy the paired label (same stem, .txt, in the corresponding labels/ folder)
    # Structure: .../images/IMG_X.jpg -> .../labels/IMG_X.txt
    label_path = Path(str(img_path).replace("\\images\\", "\\labels\\")).with_suffix(".txt")

    if label_path.exists():
        relative_label_path = label_path.relative_to(dataset_raw_root)
        dest_label_path = INVALID_DIR / "obstacle_detection_kaggle" / relative_label_path
        dest_label_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            shutil.copy2(label_path, dest_label_path)
            logger.warning(f"[MOVED TO INVALID] obstacle_detection_kaggle — {relative_label_path} — reason: paired image is cross-split duplicate")
            copied_leakage.append({"file": str(relative_label_path), "type": "label"})
        except Exception as e:
            logger.error(f"[COPY FAILED] obstacle_detection_kaggle — {relative_label_path} — {e}")
    else:
        logger.warning(f"[NO PAIRED LABEL] obstacle_detection_kaggle — {img_path} — expected label not found at {label_path}")

copied_leakage_df = pd.DataFrame(copied_leakage)
print(f"Copied {len(copied_leakage_df)} files (images + labels) into invalid/ due to cross-split leakage")
print(copied_leakage_df["type"].value_counts())
# Out:
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20825.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20825.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20829.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20829.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20833.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20833.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20841.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20841.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20853.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20853.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20856.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20856.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20861.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20861.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20862.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20862.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20867.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20867.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20870.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20870.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20872.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20872.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_20875.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20875.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_21019.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21019.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_21095.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21095.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_21154.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21154.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_21204.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21204.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_21228.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21228.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22208.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22208.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22209.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22209.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22211.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22211.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22212.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22212.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22214.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22214.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22215.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22215.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22216.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22216.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22219.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22219.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22220.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22220.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22223.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22223.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22226.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22226.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22233.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22233.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22234.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22234.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22235.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22235.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22246.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22246.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22248.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22248.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22254.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22254.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22255.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22255.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22256.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22256.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22257.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22257.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22258.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22258.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22259.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22259.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22263.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22263.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22264.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22264.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22271.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22271.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22272.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22272.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22282.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22282.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22286.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22286.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22288.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22288.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22290.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22290.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22292.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22292.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22299.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22299.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22300.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22300.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22301.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22301.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22305.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22305.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22307.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22307.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22308.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22308.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22309.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22309.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22310.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22310.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22311.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22311.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22312.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22312.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22313.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22313.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22321.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22321.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_22322.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_22322.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_23034.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23034.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\images\IMG_23035.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23035.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20821.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20821.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20825.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20825.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20828.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20828.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20833.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20833.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20834.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20834.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20835.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20835.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20838.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20838.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20839.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20839.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20841.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20841.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20847.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20847.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20850.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20850.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20853.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20853.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20855.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20855.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20856.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20856.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20858.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20858.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20860.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20860.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20861.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20861.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20862.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20862.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20867.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20867.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20870.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20870.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20871.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20871.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20872.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20872.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20874.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20874.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20875.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20875.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19205.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19205.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20883.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20883.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23289.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23289.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23297.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23297.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23331.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23331.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23335.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23335.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23505.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23505.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23510.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23510.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23514.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23514.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23516.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23516.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23517.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23517.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23944.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_23944.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20906.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20906.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19248.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19248.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20965.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20965.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20966.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20966.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20967.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20967.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19253.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19253.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20971.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20971.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20974.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20974.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19257.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19257.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20976.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20976.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20977.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20977.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20979.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20979.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20982.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20982.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20983.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20983.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20984.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20984.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20985.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20985.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19260.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19260.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20987.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20987.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20988.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20988.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20989.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20989.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20991.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20991.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19262.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19262.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20993.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20993.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20994.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20994.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20999.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_20999.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21004.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21004.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21005.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21005.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21006.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21006.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19475.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19475.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21007.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21007.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21008.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21008.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21665.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21665.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21666.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21666.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21667.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21667.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21009.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21009.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21011.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21011.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21013.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21013.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19273.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19273.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21017.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21017.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21018.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21018.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19270.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19270.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21022.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21022.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21096.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21096.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19571.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19571.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21025.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21025.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21026.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21026.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21027.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21027.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21654.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21654.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21655.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21655.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21656.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21656.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21028.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21028.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21031.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21031.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21033.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21033.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21035.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21035.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21036.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21036.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21041.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21041.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19290.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19290.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21043.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21043.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21044.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21044.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21046.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21046.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19292.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19292.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21048.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21048.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21049.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21049.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19297.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19297.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21057.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21057.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21061.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21061.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21064.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21064.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19301.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19301.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\valid\labels\IMG_21065.txt — reason: cross-split duplicate
# ...
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19781.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\images\IMG_19782.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19782.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\images\IMG_19787.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19787.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\images\IMG_19790.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19790.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\images\IMG_19795.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19795.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\images\IMG_19798.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19798.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\images\IMG_19801.jpg — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19801.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19189.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19189.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19191.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19191.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19195.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19195.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19196.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19196.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19199.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19199.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19202.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19202.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19217.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19217.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19251.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19251.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19264.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19264.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19286.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19286.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19294.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19294.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19296.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19296.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19367.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19367.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19510.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19510.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19514.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19514.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19563.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19563.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19581.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19581.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19607.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19607.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19613.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19613.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19624.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19624.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19629.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19629.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19684.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19684.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19785.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19785.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20540.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20540.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19680.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_19680.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20413.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20413.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20414.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20414.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20415.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20415.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20417.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20417.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20420.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20420.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20418.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20418.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20424.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20424.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20422.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20422.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20423.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20423.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20426.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20426.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20427.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20427.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20429.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20429.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20430.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20430.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20435.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20435.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20436.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20436.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20477.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20477.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20482.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20482.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20710.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20710.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20677.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20677.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20706.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20706.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20707.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20707.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20732.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20732.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20746.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20746.txt — reason: paired image is cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20735.txt — reason: cross-split duplicate
# WARNING: [MOVED TO INVALID] obstacle_detection_kaggle — ROD-Dataset\dataset\test\labels\IMG_20735.txt — reason: paired image is cross-split duplicate
# Copied 1148 files (images + labels) into invalid/ due to cross-split leakage
# type
# image    574
# label    574
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# Final confirmation against yaml
#
# ---

# %%
# --- Step 6: Formal cross-check against download_sheet.yaml ---

yaml_check_results = []

for name, meta in datasets.items():
    status = meta.get("status")
    source = meta.get("source")
    folder_name = meta.get("folder")
    license_info = meta.get("ethics", {}).get("license")

    entry = {
        "dataset": name,
        "yaml_status": status,
        "yaml_source": source,
        "yaml_folder": folder_name,
        "yaml_license": license_info,
    }

    if status == "rejected":
        entry["pipeline_action"] = "SKIPPED"
        entry["notes"] = "Correctly excluded — not downloaded/validated per YAML status."
        yaml_check_results.append(entry)
        continue

    # Confirm this dataset actually went through folder + integrity checks
    in_folder_check = name in folder_check_df["dataset"].values
    in_integrity_check = name in file_integrity_df["dataset"].values if "file_integrity_df" in dir() else False

    folder_row = folder_check_df[folder_check_df["dataset"] == name]
    actual_verdict = folder_row["verdict"].values[0] if len(folder_row) else "NOT_FOUND"
    expected_path_exists = actual_verdict == "OK"

    entry["pipeline_action"] = "VALIDATED" if expected_path_exists else "MISSING/INCOMPLETE"
    entry["in_folder_check"] = in_folder_check
    entry["in_integrity_check"] = in_integrity_check
    entry["folder_verdict"] = actual_verdict

    if not expected_path_exists:
        entry["notes"] = "MISMATCH — approved in YAML but not found/processed correctly."
        logger.error(f"[YAML CROSS-CHECK] {name} — approved in YAML but folder verdict is '{actual_verdict}'")
    else:
        entry["notes"] = "OK — matches YAML, processed through pipeline."

    yaml_check_results.append(entry)

yaml_check_df = pd.DataFrame(yaml_check_results)
print(yaml_check_df.to_string(index=False))

# Explicit final tally
approved_count = sum(1 for m in datasets.values() if m.get("status") == "approved")
rejected_count = sum(1 for m in datasets.values() if m.get("status") == "rejected")
processed_ok = (yaml_check_df["pipeline_action"] == "VALIDATED").sum()

print(f"\nYAML total datasets   : {len(datasets)}")
print(f"Approved in YAML      : {approved_count}")
print(f"Rejected/skipped      : {rejected_count}")
print(f"Successfully processed: {processed_ok}")
print(f"Mismatch/missing      : {approved_count - processed_ok}")

logger.info(f"[YAML CROSS-CHECK COMPLETE] {processed_ok}/{approved_count} approved datasets fully processed. "
            f"{rejected_count} correctly skipped.")
# Out:
# INFO: [YAML CROSS-CHECK COMPLETE] 18/18 approved datasets fully processed. 1 correctly skipped.
#                               dataset yaml_status yaml_source                    yaml_folder                      yaml_license pipeline_action in_folder_check in_integrity_check folder_verdict                                                          notes
#           obstacle_detection_roboflow    approved    roboflow    obstacle_detection_roboflow                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#             obstacle_detection_kaggle    approved      kaggle      obstacle_detection_kaggle                               MIT       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#        obstacle_detection_huggingface    rejected huggingface obstacle_detection_huggingface                               MIT         SKIPPED             NaN                NaN            NaN Correctly excluded — not downloaded/validated per YAML status.
#               indoor_object_detection    approved      kaggle        indoor_object_detection GNU Lesser General Public License       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                      mapillary_vistas    approved      manual               mapillary_vistas                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                           light_poles    approved      kaggle                    light_poles                        Apache 2.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#            fpv_crosswalk_segmentation    approved      kaggle     fpv_crosswalk_segmentation                      CC BY-SA 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                  pedestrian_detection    approved      kaggle           pedestrian_detection                 CC0 Public Domain       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                   road_sign_detection    approved      kaggle            road_sign_detection                 CC0 Public Domain       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                          antic_chairs    approved      kaggle                   antic_chairs                 CC0 Public Domain       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                       doors_detection    approved      kaggle                doors_detection                 CC0 Public Domain       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#               indoor_objects_roboflow    approved    roboflow        indoor_objects_roboflow                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#              indoor_detection_vineeth    approved    roboflow       indoor_detection_vineeth                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                  indoor_objects_5iwhq    approved    roboflow           indoor_objects_5iwhq                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
# revised_pedestrian_obstacle_detection    approved    roboflow  pedestrian_obstacle_detection                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                       pedestrian_walk    approved    roboflow                pedestrian_walk                     Public Domain       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                       outdoor_objects    approved    roboflow                outdoor_objects                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                    footpath_detection    approved    roboflow             footpath_detection                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#                      stairs_detection    approved    roboflow               stairs_detection                         CC BY 4.0       VALIDATED            True               True             OK                 OK — matches YAML, processed through pipeline.
#
# YAML total datasets   : 19
# Approved in YAML      : 18
# Rejected/skipped      : 1
# Successfully processed: 18
# Mismatch/missing      : 0

# %% [markdown]
# ---
#
# Empty the validated folder before moving
#
# ---

# %%
if VALIDATED_DIR.exists():
    shutil.rmtree(VALIDATED_DIR)
VALIDATED_DIR.mkdir(parents=True, exist_ok=True)

print("validated/ cleared and recreated.")
# Out:
# validated/ cleared and recreated.

# %% [markdown]
# ---
#
# Copy non-invalid data into validated folder
#
# ---

# %%
validated_copy_log = []

stream_handler.setLevel(logging.CRITICAL)
try:
    for row in folder_check_df.itertuples():
        if row.verdict != "OK":
            continue

        dataset_name = row.dataset
        dataset_path = Path(row.path)
        source = datasets[dataset_name]["source"]

        all_files = [f for f in dataset_path.rglob("*") if f.is_file()]

        copied = 0
        skipped_metadata = 0
        skipped_invalid = 0

        for f in tqdm(all_files, desc=dataset_name, leave=False):
            if is_metadata(f):
                skipped_metadata += 1
                continue
            if str(f.resolve()) in excluded_paths:
                skipped_invalid += 1
                continue

            relative_path = f.relative_to(dataset_path)
            dest_path = VALIDATED_DIR / source / dataset_name / relative_path
            dest_path.parent.mkdir(parents=True, exist_ok=True)

            try:
                shutil.copy2(f, dest_path)
                copied += 1
            except Exception as e:
                logger.error(f"[VALIDATED COPY FAILED] {dataset_name} — {f} — {e}")

        logger.info(f"[VALIDATED] {dataset_name} — copied: {copied}, "
                    f"skipped_metadata: {skipped_metadata}, skipped_invalid: {skipped_invalid}")

        validated_copy_log.append({
            "dataset": dataset_name,
            "total_files": len(all_files),
            "copied_to_validated": copied,
            "skipped_metadata": skipped_metadata,
            "skipped_invalid": skipped_invalid
        })
finally:
    stream_handler.setLevel(logging.INFO)

validated_copy_df = pd.DataFrame(validated_copy_log)
print(validated_copy_df.to_string(index=False))
# Out:
#                               dataset  total_files  copied_to_validated  skipped_metadata  skipped_invalid
#           obstacle_detection_roboflow        18369                18253                 3              113
#             obstacle_detection_kaggle        48658                47932                 3              723
#               indoor_object_detection         2692                 2533                 1              158
#                      mapillary_vistas       165009               165008                 1                0
#                           light_poles         1826                 1819                 0                7
#            fpv_crosswalk_segmentation         6600                 6600                 0                0
#                  pedestrian_detection            6                    6                 0                0
#                   road_sign_detection         1754                 1754                 0                0
#                          antic_chairs         1403                 1403                 0                0
#                       doors_detection          208                  208                 0                0
#               indoor_objects_roboflow          263                  260                 3                0
#              indoor_detection_vineeth         5783                 5779                 3                1
#                  indoor_objects_5iwhq         2981                 2975                 3                3
# revised_pedestrian_obstacle_detection        12687                12527                 3              157
#                       pedestrian_walk         2003                 2000                 3                0
#                       outdoor_objects         4803                 4761                 3               39
#                    footpath_detection         3377                 3225                 3              149
#                      stairs_detection          469                  462                 3                4

# %% [markdown]
# ---
#
# Verification of the file moving (you might notice some missing files, yes, those are README and some unnecessary stuff)
#
# ---

# %%
# --- Verify actual file counts on disk in validated/ and invalid/ ---

validated_actual = sum(1 for f in VALIDATED_DIR.rglob("*") if f.is_file())
invalid_actual = sum(1 for f in INVALID_DIR.rglob("*") if f.is_file())
raw_total = sum(1 for f in RAW_DIR.rglob("*") if f.is_file())

print(f"raw/       : {raw_total} files")
print(f"validated/ : {validated_actual} files")
print(f"invalid/   : {invalid_actual} files")
print(f"validated + invalid = {validated_actual + invalid_actual}")
print(f"(raw includes huggingface's empty folder + all metadata files not copied anywhere)")
# Out:
# raw/       : 278891 files
# validated/ : 277505 files
# invalid/   : 1354 files
# validated + invalid = 278859
# (raw includes huggingface's empty folder + all metadata files not copied anywhere)

# %% [markdown]
# ---
#
# Report consolidation and log closing
#
# ---

# %%
report_rows = []

for row in folder_check_df.itertuples():
    dataset_name = row.dataset

    if row.verdict == "SKIPPED":
        report_rows.append({
            "dataset": dataset_name,
            "yaml_status": "rejected",
            "source": None,
            "license": None,
            "total_raw_files": None,
            "validated_files": None,
            "invalid_files": None,
            "metadata_files": None,
            "verdict": "SKIPPED"
        })
        continue

    meta = datasets[dataset_name]
    vc_row = validated_copy_df[validated_copy_df["dataset"] == dataset_name]

    total_raw = vc_row["total_files"].values[0] if len(vc_row) else None
    copied_validated = vc_row["copied_to_validated"].values[0] if len(vc_row) else None
    skipped_meta = vc_row["skipped_metadata"].values[0] if len(vc_row) else None
    skipped_inv = vc_row["skipped_invalid"].values[0] if len(vc_row) else None

    report_rows.append({
        "dataset": dataset_name,
        "yaml_status": meta.get("status"),
        "source": meta.get("source"),
        "license": meta.get("ethics", {}).get("license"),
        "total_raw_files": total_raw,
        "validated_files": copied_validated,
        "invalid_files": skipped_inv,
        "metadata_files": skipped_meta,
        "verdict": "PROCESSED"
    })

final_report_df = pd.DataFrame(report_rows)

# Write the summary CSV
report_path = REPORT_DIR / f"validation_report_{timestamp}.csv"
final_report_df.to_csv(report_path, index=False)

# Write the detailed issue-level CSV (every individual flagged file, across all checks)
all_issues = []

for issue in file_level_issues:
    all_issues.append({"dataset": issue["dataset"], "file": issue["file"], "category": "corrupt", "reason": issue["issue"]})
for rec in orphan_records:
    all_issues.append({"dataset": rec["dataset"], "file": rec["file"], "category": "orphan", "reason": rec["type"]})
for row in bad_label_files.itertuples():
    all_issues.append({"dataset": row.dataset, "file": row.file, "category": "bad_annotation", "reason": "invalid annotation content"})
for row in removed_df.itertuples():
    all_issues.append({"dataset": "obstacle_detection_kaggle", "file": row.removed, "category": "cross_split_duplicate", "reason": f"duplicate, kept: {row.kept}"})

all_issues_df = pd.DataFrame(all_issues)
issues_path = REPORT_DIR / f"validation_issues_{timestamp}.csv"
all_issues_df.to_csv(issues_path, index=False)

# Final log entries
logger.info("=" * 60)
logger.info("VALIDATION RUN COMPLETE")
logger.info(f"Total datasets in YAML       : {len(datasets)}")
logger.info(f"Approved and processed       : {(final_report_df['verdict'] == 'PROCESSED').sum()}")
logger.info(f"Skipped (rejected in YAML)   : {(final_report_df['verdict'] == 'SKIPPED').sum()}")
logger.info(f"Total files in validated/    : {final_report_df['validated_files'].sum()}")
logger.info(f"Total files in invalid/      : {int(final_report_df['invalid_files'].sum())}")
logger.info(f"Summary report written to    : {report_path}")
logger.info(f"Detailed issues written to   : {issues_path}")
logger.info("=" * 60)

# Close file handler cleanly
file_handler.close()
logger.removeHandler(file_handler)

print("Validation complete.")
print(f"\nSummary report : {report_path}")
print(f"Detailed issues: {issues_path}")
print(f"\n{final_report_df.to_string(index=False)}")
# Out:
# INFO: ============================================================
# INFO: VALIDATION RUN COMPLETE
# INFO: Total datasets in YAML       : 19
# INFO: Approved and processed       : 18
# INFO: Skipped (rejected in YAML)   : 1
# INFO: Total files in validated/    : 277505.0
# INFO: Total files in invalid/      : 1354
# INFO: Summary report written to    : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\reports\validation_report_20260804_012057.csv
# INFO: Detailed issues written to   : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\reports\validation_issues_20260804_012057.csv
# INFO: ============================================================
# Validation complete.
#
# Summary report : D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\reports\validation_report_20260804_012057.csv
# Detailed issues: D:\SIT374\WalkBuddy-T2-2026\ML_side\datasets\reports\validation_issues_20260804_012057.csv
#
#                               dataset yaml_status   source                           license  total_raw_files  validated_files  invalid_files  metadata_files   verdict
#           obstacle_detection_roboflow    approved roboflow                         CC BY 4.0          18369.0          18253.0          113.0             3.0 PROCESSED
#             obstacle_detection_kaggle    approved   kaggle                               MIT          48658.0          47932.0          723.0             3.0 PROCESSED
#        obstacle_detection_huggingface    rejected     None                              None              NaN              NaN            NaN             NaN   SKIPPED
#               indoor_object_detection    approved   kaggle GNU Lesser General Public License           2692.0           2533.0          158.0             1.0 PROCESSED
#                      mapillary_vistas    approved   manual                         CC BY 4.0         165009.0         165008.0            0.0             1.0 PROCESSED
#                           light_poles    approved   kaggle                        Apache 2.0           1826.0           1819.0            7.0             0.0 PROCESSED
#            fpv_crosswalk_segmentation    approved   kaggle                      CC BY-SA 4.0           6600.0           6600.0            0.0             0.0 PROCESSED
#                  pedestrian_detection    approved   kaggle                 CC0 Public Domain              6.0              6.0            0.0             0.0 PROCESSED
#                   road_sign_detection    approved   kaggle                 CC0 Public Domain           1754.0           1754.0            0.0             0.0 PROCESSED
#                          antic_chairs    approved   kaggle                 CC0 Public Domain           1403.0           1403.0            0.0             0.0 PROCESSED
#                       doors_detection    approved   kaggle                 CC0 Public Domain            208.0            208.0            0.0             0.0 PROCESSED
#               indoor_objects_roboflow    approved roboflow                         CC BY 4.0            263.0            260.0            0.0             3.0 PROCESSED
#              indoor_detection_vineeth    approved roboflow                         CC BY 4.0           5783.0           5779.0            1.0             3.0 PROCESSED
#                  indoor_objects_5iwhq    approved roboflow                         CC BY 4.0           2981.0           2975.0            3.0             3.0 PROCESSED
# revised_pedestrian_obstacle_detection    approved roboflow                         CC BY 4.0          12687.0          12527.0          157.0             3.0 PROCESSED
#                       pedestrian_walk    approved roboflow                     Public Domain           2003.0           2000.0            0.0             3.0 PROCESSED
#                       outdoor_objects    approved roboflow                         CC BY 4.0           4803.0           4761.0           39.0             3.0 PROCESSED
#                    footpath_detection    approved roboflow                         CC BY 4.0           3377.0           3225.0          149.0             3.0 PROCESSED
#                      stairs_detection    approved roboflow                         CC BY 4.0            469.0            462.0            4.0             3.0 PROCESSED

# %% [markdown]
# ---
#
# And that's the end of the validation process, this line conclude the notebook and one's can move onto the next one.
# There might be some code duplication such as the creation of the folders from the collection step, but I'll complete it along the way as soon as the dataset is ready.
#
# ---
